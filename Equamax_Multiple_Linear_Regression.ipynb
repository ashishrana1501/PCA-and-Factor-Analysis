# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Importing filterwarnings to ignore warning messages**

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Import Required Library**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from scipy.stats import shapiro, bartlett
from sklearn import metrics
from statsmodels.stats.stattools import durbin_watson

# %% [markdown]
# **Importing Dataset**

# %%
data = pd.read_excel("/content/drive/MyDrive/Projects/MVD/Equamax.xlsx")

# %%
data
# Out:
#              0         1         2         3         4  Life_Expectancy
# 0    -1.321170  2.554592  0.151215  0.743292 -1.424271             65.0
# 1     0.913394 -0.858197 -0.089657  0.376767 -0.305957             77.8
# 2     0.714836  0.425719  0.023964 -0.286196 -0.868309             75.6
# 3    -1.385206  0.436653  0.140758  1.298880  1.185643             52.4
# 4     0.697782 -0.236763  0.442916  0.361209 -0.457063             76.4
# ...        ...       ...       ...       ...       ...              ...
# 2933 -0.705955 -0.783623 -0.281348 -0.650759 -0.660830             72.5
# 2934  0.939729  2.900209  0.029180 -0.004348 -0.945605             73.4
# 2935 -0.464618  2.206387 -0.299859  0.392579 -1.061399             68.0
# 2936  0.187417  0.497910 -0.796920  0.821276  1.798789             45.6
# 2937 -0.238343  1.515518 -0.521852 -0.238842  1.372909             46.0
#
# [2938 rows x 6 columns]

# %% [markdown]
# **Data Pre-Processing**

# %% [markdown]
# **Creating a copy of original dataset**

# %%
df = data.copy()

# %%
df.columns = ['Immunization', 'Thinness','Economic_and_Social', 'Children','Mortality','Life_Expectancy']

# %%
df.head(10)
# Out:
#    Immunization  Thinness  Economic_and_Social  Children  Mortality  \
# 0     -1.321170  2.554592             0.151215  0.743292  -1.424271
# 1      0.913394 -0.858197            -0.089657  0.376767  -0.305957
# 2      0.714836  0.425719             0.023964 -0.286196  -0.868309
# 3     -1.385206  0.436653             0.140758  1.298880   1.185643
# 4      0.697782 -0.236763             0.442916  0.361209  -0.457063
# 5      0.354316 -0.678763             0.672916 -0.516062  -0.370359
# 6      0.559251 -0.639332            -0.614023 -0.850911  -0.536829
# 7      0.207995 -0.672271             1.255364 -0.680794  -0.488354
# 8      0.395898 -0.430093             1.028508  0.429250  -0.506497
# 9      0.735809 -0.426959            -0.577358 -0.705237  -0.606301
#
#    Life_Expectancy
# 0             65.0
# 1             77.8
# 2             75.6
# 3             52.4
# 4             76.4
# 5             76.3
# 6             74.8
# 7             82.8
# 8             81.5
# 9             72.7

# %%
df.tail(10)
# Out:
#       Immunization  Thinness  Economic_and_Social  Children  Mortality  \
# 2928     -0.328697  0.621309            -0.120148  2.544134   1.355415
# 2929     -0.624892 -1.264893            -0.609670 -0.133389  -0.235797
# 2930     -1.603592 -0.708131             0.836376 -1.126902  -0.602885
# 2931      0.989994 -0.608289            -1.702196 -0.032737   0.065568
# 2932     -1.018605 -1.296632            -1.443010  0.732863  -0.870109
# 2933     -0.705955 -0.783623            -0.281348 -0.650759  -0.660830
# 2934      0.939729  2.900209             0.029180 -0.004348  -0.945605
# 2935     -0.464618  2.206387            -0.299859  0.392579  -1.061399
# 2936      0.187417  0.497910            -0.796920  0.821276   1.798789
# 2937     -0.238343  1.515518            -0.521852 -0.238842   1.372909
#
#       Life_Expectancy
# 2928             49.2
# 2929             76.8
# 2930             75.1
# 2931             67.1
# 2932             69.0
# 2933             72.5
# 2934             73.4
# 2935             68.0
# 2936             45.6
# 2937             46.0

# %% [markdown]
# **To Find Data type and missing values in data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Immunization         2938 non-null   float64
#  1   Thinness             2938 non-null   float64
#  2   Economic_and_Social  2938 non-null   float64
#  3   Children             2938 non-null   float64
#  4   Mortality            2938 non-null   float64
#  5   Life_Expectancy      2938 non-null   float64
# dtypes: float64(6)
# memory usage: 137.8 KB

# %% [markdown]
# 1.   No missing values present in the data set.
# 2.   Independent variables are of float data type where as dependent variable(Life_Expectancy) are of float data type.

# %%
df.shape
# Out:
# (2938, 6)

# %%
df.size
# Out:
# 17628

# %% [markdown]
# **Descriptive statistics**

# %%
df.describe()
# Out:
#        Immunization      Thinness  Economic_and_Social      Children  \
# count  2.938000e+03  2.938000e+03         2.938000e+03  2.938000e+03
# mean   5.162461e-16 -6.665873e-17        -2.036039e-16 -2.418741e-16
# std    9.541313e-01  9.666662e-01         9.106627e-01  1.001376e+00
# min   -2.941146e+00 -1.807863e+00        -1.995850e+00 -1.828125e+00
# 25%   -4.943799e-01 -6.985537e-01        -6.541442e-01 -8.266891e-01
# 50%    2.887136e-01 -2.936809e-01        -1.897981e-01 -2.329623e-01
# 75%    7.165305e-01  5.554050e-01         4.425118e-01  6.798988e-01
# max    1.539462e+00  3.027319e+00         2.684924e+00  2.987188e+00
#
#           Mortality  Life_Expectancy
# count  2.938000e+03      2938.000000
# mean  -1.630191e-16        69.248795
# std    8.286796e-01         9.462136
# min   -2.020690e+00        45.600000
# 25%   -5.684316e-01        63.200000
# 50%   -1.754075e-01        72.000000
# 75%    4.218994e-01        75.600000
# max    2.379419e+00        89.000000

# %% [markdown]
# *   describe() function tell us five number summary that is min, max, quartile, mean, count.

# %% [markdown]
# **Finding Missing values in data set if any**

# %%
df.isnull().sum()
# Out:
# Immunization           0
# Thinness               0
# Economic_and_Social    0
# Children               0
# Mortality              0
# Life_Expectancy        0
# dtype: int64

# %% [markdown]
# *   Here we can see that, there are no missing values present in data

# %% [markdown]
# **Correlation**

# %%
df.corr()
# Out:
#                      Immunization  Thinness  Economic_and_Social  Children  \
# Immunization             1.000000 -0.004209             0.050414 -0.006911
# Thinness                -0.004209  1.000000            -0.047957  0.000593
# Economic_and_Social      0.050414 -0.047957             1.000000 -0.001003
# Children                -0.006911  0.000593            -0.001003  1.000000
# Mortality               -0.036187  0.013406            -0.080446  0.003370
# Life_Expectancy          0.444509 -0.372747             0.554459 -0.146001
#
#                      Mortality  Life_Expectancy
# Immunization         -0.036187         0.444509
# Thinness              0.013406        -0.372747
# Economic_and_Social  -0.080446         0.554459
# Children              0.003370        -0.146001
# Mortality             1.000000        -0.519301
# Life_Expectancy      -0.519301         1.000000

# %% [markdown]
# *   Independent variable is Highly Correlated with dependent variable with the value of correlation 0.98

# %% [markdown]
# **Data Visualization**

# %%
plt.figure(figsize= (15,10))
sns.heatmap(df.corr(),
            cmap="Paired", 
            linecolor = "white" ,
            linewidth= 4 ,  
            cbar= "cividis" ,
            annot=True)
plt.show()

# %% [markdown]
# **Checking Assumption of Linear Regression**

# %% [markdown]
# **Linearity**
#
#
# > Linear regression needs the relationship between the independent and dependent variables to be linear. Let's use a pair plot to check the relation of independent variables with the Sales variable

# %%
# Lineaerity ans Normality test
plt.figure(figsize = (15,10))
sns.set(style = "ticks", color_codes = True, font_scale = 2)
g = sns.pairplot(df, height = 3, diag_kind = "hist", kind = "reg")
g.fig.suptitle("Scatter Plot")
# Out:
# Text(0.5, 0.98, 'Scatter Plot')

# %% [markdown]
# **From Scatter Plot We can observe that there is a positive linear correlation between Temperature and Revenue.**

# %% [markdown]
# **Data Prepration**

# %% [markdown]
# **Dividing the data frame to independent and dependent variable**

# %%
#Setting the value for X and Y
x = df[['Immunization', 'Thinness','Economic_and_Social', 'Children','Mortality']]
y = df['Life_Expectancy']

# %%
x
# Out:
#       Immunization  Thinness  Economic_and_Social  Children  Mortality
# 0        -1.321170  2.554592             0.151215  0.743292  -1.424271
# 1         0.913394 -0.858197            -0.089657  0.376767  -0.305957
# 2         0.714836  0.425719             0.023964 -0.286196  -0.868309
# 3        -1.385206  0.436653             0.140758  1.298880   1.185643
# 4         0.697782 -0.236763             0.442916  0.361209  -0.457063
# ...            ...       ...                  ...       ...        ...
# 2933     -0.705955 -0.783623            -0.281348 -0.650759  -0.660830
# 2934      0.939729  2.900209             0.029180 -0.004348  -0.945605
# 2935     -0.464618  2.206387            -0.299859  0.392579  -1.061399
# 2936      0.187417  0.497910            -0.796920  0.821276   1.798789
# 2937     -0.238343  1.515518            -0.521852 -0.238842   1.372909
#
# [2938 rows x 5 columns]

# %%
y
# Out:
# 0       65.0
# 1       77.8
# 2       75.6
# 3       52.4
# 4       76.4
#         ...
# 2933    72.5
# 2934    73.4
# 2935    68.0
# 2936    45.6
# 2937    46.0
# Name: Life_Expectancy, Length: 2938, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(x)

# %% [markdown]
# **Spliting the X,Y into train and test**

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y,
                                test_size=0.2, random_state=0)

# %% [markdown]
# **Training the Algorithm**

# %%
regressor = LinearRegression()
regressor.fit(x_train,y_train)
print("Training Successfully Completed")
# Out:
# Training Successfully Completed

# %%
regressor.score(x_train,y_train)
# Out:
# 0.8294500120296817

# %%
#Printing the model coefficients
print(regressor.intercept_)
# Out:
# 69.23938362107737

# %%
# pair the feature names with the coefficients
list(zip(X, regressor.coef_))
# Out:
# [(array([-1.38491954,  2.64313248,  0.1660772 ,  0.74239688, -1.71901644]),
#   3.772709682464206),
#  (array([ 0.95746703, -0.88794168, -0.0984691 ,  0.37631312, -0.36927317]),
#   -3.1969253044319617),
#  (array([ 0.74932845,  0.44047403,  0.02631972, -0.28585094, -1.04800082]),
#   4.487209091490762),
#  (array([-1.4520454 ,  0.45178701,  0.15459278,  1.29731645,  1.43100577]),
#   -1.3562463209259368),
#  (array([ 0.73145121, -0.24496922,  0.48644982,  0.36077421, -0.55164908]),
#   -4.367730352186371)]

# %%
print("Training Score:",regressor.score(x_train,y_train))
print("Test Score:",regressor.score(x_test,y_test))
# Out:
# Training Score: 0.8294500120296817
# Test Score: 0.842545612000811

# %%
print('Intercept is :',regressor.intercept_)
print('Coefficient is :',regressor.coef_)
# Out:
# Intercept is : 69.23938362107737
# Coefficient is : [ 3.77270968 -3.1969253   4.48720909 -1.35624632 -4.36773035]

# %%
y_predic = regressor.predict(x_test)
y_predic
# Out:
# array([75.18089018, 58.91127338, 79.83387326, 52.43856304, 77.23666007,
#        68.08747987, 80.40369285, 78.25817035, 60.62457828, 56.63201291,
#        80.25239618, 75.2016287 , 64.81345652, 75.73334345, 80.08362463,
#        80.89818609, 75.1985691 , 60.11908708, 73.43626053, 69.35852147,
#        75.56130574, 51.65140409, 57.12615382, 75.55301811, 70.80135082,
#        75.45490245, 71.94200409, 74.247775  , 73.55514741, 75.77005422,
#        78.07222823, 66.47647008, 73.08283022, 59.23081543, 66.18405033,
#        70.51939289, 75.75638477, 53.75034171, 72.02323342, 79.78395221,
#        47.62820906, 78.1038141 , 73.14172555, 73.39756023, 51.56466229,
#        63.36615311, 64.32261344, 79.71727625, 68.47894953, 66.38000756,
#        79.72042757, 57.71746361, 74.86399958, 73.60945832, 71.04388866,
#        74.82706186, 54.25896692, 74.08019416, 72.81225225, 62.82109481,
#        70.34514138, 72.8188342 , 65.25340358, 54.45013291, 79.73113584,
#        78.42675588, 71.10422035, 57.11739086, 51.70758638, 56.56507313,
#        80.26778871, 58.59423742, 73.12431768, 72.41871625, 67.03642994,
#        56.07965131, 67.59219964, 57.11571083, 59.39855003, 76.50124282,
#        56.26647272, 55.10763043, 56.43757413, 66.13018903, 79.35334183,
#        69.10016693, 69.95676818, 72.79003054, 67.0838932 , 77.09175617,
#        75.25847762, 58.96802599, 74.06061794, 60.13873517, 50.59692248,
#        54.41503031, 57.14394148, 70.10290209, 61.74724646, 74.36644933,
#        64.84604522, 72.66314871, 49.52501783, 61.72199634, 70.48159467,
#        81.08993588, 50.75957828, 61.1854207 , 74.48892535, 71.47654475,
#        75.79921374, 52.06926199, 60.7466824 , 72.68325274, 50.64736974,
#        75.83501326, 62.28156126, 61.70848662, 68.12900189, 64.99123905,
#        56.07948421, 79.69100633, 51.18779161, 56.62648559, 79.38840904,
#        79.43447714, 69.32454546, 63.7074808 , 75.36110148, 58.31333297,
#        79.99155075, 65.83441635, 67.58155627, 54.87744391, 57.15015686,
#        74.53012481, 70.25768397, 57.87470778, 77.48265009, 54.70069376,
#        70.76906953, 65.21081253, 56.92844579, 72.6637008 , 74.68997715,
#        49.39990969, 65.86659958, 58.94612682, 73.51936146, 67.62932739,
#        74.64974084, 53.08257724, 74.01609518, 74.6665995 , 78.00536694,
#        79.21132974, 73.31651478, 71.45043594, 57.28123019, 71.20166148,
#        76.98508248, 73.23634572, 71.09156553, 78.90444301, 76.8549981 ,
#        73.5070611 , 77.77781045, 55.65328966, 65.0807085 , 66.35419165,
#        73.55559633, 75.17633948, 69.49655072, 65.59835909, 58.00866503,
#        69.24112118, 76.18777856, 75.43080951, 79.78930858, 72.99362638,
#        77.09336588, 71.1094776 , 68.93253242, 72.77152548, 78.38896754,
#        76.17674941, 75.34930877, 70.79231349, 67.15487744, 76.91062115,
#        79.91667712, 72.94006021, 52.40955712, 65.52547183, 71.79306873,
#        76.89880551, 59.3186147 , 80.64106734, 67.60634907, 71.81568012,
#        77.20861977, 78.82329491, 76.62036449, 55.47774201, 57.86146374,
#        74.0535074 , 70.41395568, 78.39765765, 52.50879587, 70.30502702,
#        57.72644027, 53.42635605, 80.74998936, 76.54831555, 77.95378618,
#        73.36995196, 72.8410585 , 75.99480701, 80.70174599, 72.21020757,
#        63.61174305, 66.01500811, 81.99394648, 70.93831926, 57.61694594,
#        77.52635823, 74.46831291, 73.47793857, 73.99802971, 71.90350583,
#        70.18996882, 56.14990338, 75.97452549, 66.97942258, 80.66963705,
#        77.38428537, 80.46388227, 71.3625089 , 78.44621938, 65.40669248,
#        77.96403835, 75.36256873, 55.07511384, 80.39319051, 63.14940235,
#        76.24972687, 66.77835063, 77.44496444, 77.68844933, 62.92474001,
#        77.39289804, 72.85381746, 67.70153218, 72.75214475, 74.65126927,
#        79.79630961, 69.92330979, 55.23600391, 74.69626065, 75.04821641,
#        74.69806414, 57.20417472, 75.85200483, 54.52088802, 57.8461052 ,
#        63.60540075, 65.38756387, 64.82815116, 71.21174262, 80.66369577,
#        75.66785014, 57.46756895, 52.86627605, 74.86772783, 79.35082078,
#        72.26969037, 75.22460763, 74.600524  , 76.0373137 , 71.42473399,
#        72.54964004, 61.80374984, 73.70331793, 80.67396291, 72.06520349,
#        75.30537039, 65.59523855, 78.53907364, 78.72067612, 79.03399576,
#        76.16994167, 72.36244395, 76.53771061, 51.22314226, 59.19394439,
#        79.31752061, 76.14850023, 64.00259802, 80.46308044, 56.20145224,
#        73.40499616, 75.14474896, 63.99607636, 55.797022  , 78.9398799 ,
#        59.29336469, 75.79715769, 75.02340015, 79.04494475, 58.50215388,
#        57.13427899, 76.61687461, 79.44255277, 69.92468779, 61.17408586,
#        79.37416899, 77.96875912, 74.13495296, 75.53826337, 74.34237468,
#        57.93626771, 59.86974484, 77.53387007, 59.68860485, 71.66413079,
#        76.56124274, 57.92809943, 78.30942366, 70.13063545, 75.97271685,
#        79.43629521, 78.08935224, 70.2778125 , 71.97452736, 57.42806891,
#        78.22165839, 78.97566771, 72.44050619, 56.88811659, 73.65816473,
#        60.69613969, 54.16939857, 57.359838  , 63.61131898, 80.27288908,
#        70.19644246, 65.55111944, 76.48286247, 67.42697868, 74.6168346 ,
#        80.01169644, 72.27493946, 70.89535718, 77.59131183, 57.77404163,
#        61.22868633, 50.41880588, 74.80310825, 77.37528789, 55.00173621,
#        72.86873925, 70.04901953, 73.09194735, 74.11960769, 80.00890795,
#        78.45228182, 71.52659641, 71.20789559, 56.21552762, 78.92348978,
#        61.53204169, 73.66792795, 68.12342053, 73.839856  , 78.27592184,
#        74.71214462, 78.7442045 , 60.68694372, 68.73583986, 50.41584411,
#        57.10945337, 75.90454249, 80.33708521, 56.23417696, 70.19923715,
#        57.30726222, 51.09589211, 52.37276485, 74.85138877, 76.13063835,
#        73.09682663, 54.25929176, 71.15403622, 51.49115516, 70.70411753,
#        56.00084975, 75.27475412, 51.5832066 , 59.21537924, 71.83557197,
#        78.34666772, 72.42885548, 66.6721132 , 80.21077354, 80.55245015,
#        67.96543946, 65.44797064, 58.48145493, 66.50334618, 66.3837999 ,
#        51.00148215, 52.93402818, 74.88959324, 76.34542747, 76.92350003,
#        64.7716632 , 62.99750371, 73.27704215, 51.43902914, 75.47573027,
#        79.73021076, 77.39245255, 72.38891482, 75.88730908, 74.91533961,
#        65.11630603, 73.98139942, 77.27190046, 63.33694306, 60.9283511 ,
#        69.82735732, 60.52867675, 74.53532809, 69.93483169, 70.91610549,
#        70.7863782 , 71.76993577, 74.96496576, 75.53243276, 70.781055  ,
#        74.80587174, 72.5272523 , 71.91176475, 65.87047603, 76.3651645 ,
#        74.45131079, 74.3595215 , 65.14143971, 73.56187762, 74.18709845,
#        62.34223637, 74.41255712, 73.98866414, 77.4974757 , 57.89290502,
#        75.59513054, 66.49020277, 61.68150566, 52.44698366, 79.06082694,
#        66.63337435, 54.00034965, 53.53413397, 55.13646132, 75.11696223,
#        51.07176222, 69.5809116 , 64.06961122, 77.08082551, 75.28832284,
#        77.43087895, 71.97279903, 79.62997775, 78.3240192 , 51.35025581,
#        74.96491029, 58.66388836, 71.41881308, 61.4306216 , 76.05470657,
#        75.1881078 , 74.9341329 , 73.48273652, 62.10061791, 55.12664031,
#        73.45337785, 72.10190037, 65.02714522, 61.36960946, 60.98834446,
#        71.47831292, 73.56124103, 61.37162226, 73.79882349, 57.39707978,
#        63.10595167, 58.55781213, 73.66065723, 77.23002318, 79.13028206,
#        71.78619443, 65.59555878, 72.91386685, 70.26847006, 73.54006085,
#        70.21037231, 75.0995422 , 62.26021014, 76.57688719, 74.17315085,
#        74.16916713, 75.33240338, 62.14433336, 74.77250702, 75.91579965,
#        73.94833231, 79.28395992, 77.08189202, 71.90334403, 76.0185781 ,
#        77.01274649, 66.30072076, 71.05467692, 56.1659754 , 54.47546163,
#        63.32107883, 77.31684485, 64.18999384, 72.04921434, 75.02811824,
#        73.61345282, 72.04865519, 72.7605594 , 68.11774249, 67.64097388,
#        70.97009134, 75.02211743, 80.33435821, 51.92440272, 70.31324053,
#        70.1231977 , 74.86756686, 78.20996078, 72.76314748, 71.10173882,
#        76.76874052, 80.15817063, 63.13783752, 77.22307355, 60.9958019 ,
#        50.38360223, 78.53802341, 68.50934087, 66.8092043 , 75.67800893,
#        61.37515695, 54.90962302, 76.53285367, 73.07086562, 71.1188793 ,
#        54.89382194, 76.27611129, 68.46214907, 60.56598425, 72.53273241,
#        78.77581481, 75.88499559, 66.934341  , 76.14002183, 74.45449623,
#        71.71585213, 80.16065133, 73.2076172 , 50.82186755, 75.29824023,
#        75.45441396, 73.94814807, 80.14512955, 74.92903562, 69.62770278,
#        69.09983639, 72.3539895 , 51.02129668, 53.78055806, 71.69831003,
#        62.78634362, 60.54607406, 78.9409556 ])

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': y_predic})    
df1
# Out:
#       Actual  Predicted
# 867     74.5  75.180890
# 1780    68.0  58.911273
# 621     86.0  79.833873
# 2715    45.6  52.438563
# 2717    73.3  77.236660
# ...      ...        ...
# 1290    50.0  53.780558
# 2724    72.7  71.698310
# 392     58.6  62.786344
# 27      53.3  60.546074
# 674     81.1  78.940956
#
# [588 rows x 2 columns]

# %%
# print the R-squared value for the model
print('R squared value of the model: {:.2f}'.format(regressor.score(x,y)*100))
# Out:
# R squared value of the model: 82.21

# %% [markdown]
# **Mean of Residuals**
#
#
# > Residuals as we know are the differences between the true value and the predicted value. One of the assumptions of linear regression is that the mean of the residuals should be zero. So let's find out.

# %%
y_pred_train = regressor.predict(x_train)
residuals = y_train - y_pred_train
mean_residuals = np.mean(residuals)
print("Mean of Residuals = {}".format(mean_residuals))
# Out:
# Mean of Residuals = -4.538402750535789e-15

# %%
len(residuals)
# Out:
# 2350

# %%
residuals.shape
# Out:
# (2350,)

# %% [markdown]
# **The mean of the residuals is so small that we can consider it zero.**

# %% [markdown]
# **Check for Homoscedasticity**
#
#
#
#
# > Homoscedasticity means that the residuals have equal or almost equal variance across the regression line. By plotting the error terms with predicted terms we can check that there should not be any pattern in the error terms.

# %% [markdown]
# **Detecting heteroscedasticity!**
#
#
# > **Graphical Method:** Firstly do the regression analysis and then plot the error terms against the predicted values( Yi^). If there is a definite pattern (like linear or quadratic or funnel shaped) obtained from the scatter plot then heteroscedasticity is present.

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(y_pred_train, residuals)
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')

# %% [markdown]
# **From the scatter plot it is clear that there is no specific patters forming. So we can say homoscedasticity is present.**

# %%
# Homoscadasticity

from statsmodels.formula.api import ols

reg = ols('Life_Expectancy~Immunization+Thinness+Economic_and_Social+Children+Mortality', data = df).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.832
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     2908.
# Date:                Sun, 22 May 2022   Prob (F-statistic):               0.00
# Time:                        04:25:03   Log-Likelihood:                -8148.7
# No. Observations:                2938   AIC:                         1.631e+04
# Df Residuals:                    2932   BIC:                         1.635e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              69.2488      0.072    967.594      0.000      69.108      69.389
# Immunization            3.9785      0.075     52.936      0.000       3.831       4.126
# Thinness               -3.3451      0.074    -45.121      0.000      -3.491      -3.200
# Economic_and_Social     4.9937      0.079     63.184      0.000       4.839       5.149
# Children               -1.3322      0.071    -18.637      0.000      -1.472      -1.192
# Mortality              -5.2646      0.087    -60.715      0.000      -5.435      -5.095
# ==============================================================================
# Omnibus:                       48.583   Durbin-Watson:                   2.107
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.960
# Skew:                           0.015   Prob(JB):                     3.95e-21
# Kurtosis:                       3.876   Cond. No.                         1.23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **Goldfeld Quandt Test**
#
# **Checking heteroscedasticity :** Using Goldfeld Quandt we test for heteroscedasticity.
#
#
#
#
# > **Null Hypothesis:** Error terms are homoscedastic
#
# > **Alternative Hypothesis:** Error terms are heteroscedastic.

# %%
import statsmodels.stats.api as sms
from statsmodels.compat import lzip
name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(residuals, x_train)
lzip(name, test)
# Out:
# [('F statistic', 1.0849104884642673), ('p-value', 0.08175987067922365)]

# %% [markdown]
# Since p value is greater than 0.05 in Goldfeld Quandt Test.
# Therefore, we do not reject Null hypothesis.
# Hnece, we Conclude that error terms are homoscedastic.

# %% [markdown]
# **Check for Normality of error terms/residuals**

# %%
p = sns.distplot(residuals,kde=True)
p = plt.title('Normality of error terms/residuals')

# %% [markdown]
# **No autocorrelation of residuals**
#
# > When the residuals are autocorrelated, it means that the current value is dependent of the previous (historic) values and that there is a definite unexplained pattern in the Y variable that shows up in the error terms. Though it is more evident in time series data.
#
# > In plain terms autocorrelation takes place when there's a pattern in the rows of the data. This is usual in time series data as there is a pattern of time for eg. Week of the day effect which is a very famous pattern seen in stock markets where people tend to buy stocks more towards the beginning of weekends and tend to sell more on Mondays. There's been great study about this phenomenon and it is still a matter of research as to what actual factors cause this trend.
#
# > There should not be autocorrelation in the data so the error terms should not form any pattern.

# %%
import scipy.stats as stats

fig, ax = plt.subplots(figsize = (15,10))
stats.probplot(residuals, dist = "norm", plot = plt)
# Out:
# ((array([-3.43625043, -3.1881843 , -3.0507607 , ...,  3.0507607 ,
#           3.1881843 ,  3.43625043]),
#   array([-14.20850098, -14.14048633, -13.86152434, ...,  12.7033241 ,
#           13.17929238,  14.68579261])),
#  (3.8790128594190882, -5.400707186624732e-15, 0.9946627028173367))

# %%
plt.figure(figsize=(15,10))
sns.lineplot(y_pred_train, residuals, marker = 'o', linestyle = '--')
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.title('Residuals vs fitted values plot for autocorrelation check')
plt.show()

# %% [markdown]
# **Checking for autocorrelation To ensure the absence of autocorrelation we use Ljungbox test.**
#
# > **Null Hypothesis:** Autocorrelation is absent.
#
# > **Alternative Hypothesis:** Autocorrelation is present.

# %%
from statsmodels.stats import diagnostic as diag
min(diag.acorr_ljungbox(residuals , lags = 40)[1])
# Out:
# 0.31947149919915235

# %% [markdown]
# **Since p value is greater than 0.05 we do not reject the null hypothesis that error terms are not autocorrelated.**

# %% [markdown]
# **No perfect multicollinearity**
#
# > In regression, multicollinearity refers to the extent to which independent variables are correlated. Multicollinearity affects the coefficients and p-values, but it does not influence the predictions, precision of the predictions, and the goodness-of-fit statistics. If your primary goal is to make predictions, and you don’t need to understand the role of each independent variable, you don’t need to reduce severe multicollinearity.

# %%
plt.figure(figsize=(20,20))  # on this line I just set the size of figure to 12 by 10.
p=sns.heatmap(df.corr(), annot=True,cmap='RdYlGn',square=True,linewidth= 4)  # seaborn has very simple solution for heatmap

# %% [markdown]
# **Model Evaluation**

# %%
# Importing metrics from sklearn 
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
# To find Mean Absolute Error(mse)
mse = (mean_absolute_error(y_test, y_predic))
print("MAE:",mse)
# Out:
# MAE: 2.858945042503749

# %%
# To find Root Mean Squared Error(rmse)
rmse = (np.sqrt(mean_squared_error(y_test, y_predic)))
print("RMSE:",rmse)
# Out:
# RMSE: 3.800606621431235

# %%
# To find coefficient of determination
r2 =  r2_score(y_test, y_predic)
print("R-Square:",r2)
# Out:
# R-Square: 0.842545612000811

# %%
# 0 means the model is perfect. Therefore the value should be as close to 0 as possible
meanAbErr = metrics.mean_absolute_error(y_test, y_predic)
meanSqErr = metrics.mean_squared_error(y_test, y_predic)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_predic))
MAPE = metrics.mean_absolute_percentage_error(y_test, y_predic)

print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
print('Mean Absolute Percenatge Error:', MAPE)
# Out:
# Mean Absolute Error: 2.858945042503749
# Mean Square Error: 14.444610690866947
# Root Mean Square Error: 3.800606621431235
# Mean Absolute Percenatge Error: 0.04302330442498607

# %% [markdown]
# **Linearity**

# %%
plt.figure(figsize=(15,15))
sns.regplot(y_test, y_predic)
plt.xlabel('Actual')
plt.ylabel('Predicted')
p = plt.title('Actual vs Predicted')
